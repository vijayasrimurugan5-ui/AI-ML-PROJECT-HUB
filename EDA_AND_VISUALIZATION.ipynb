# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/preprocessing_dataset.csv')

# %%
df.head()
# Out:
#       Name   Age Gender   Salary Department
# 0    Alice  25.0      F  50000.0         HR
# 1      Bob  30.0      M  60000.0    Finance
# 2  Charlie   NaN      M  55000.0         IT
# 3    David  40.0      M  58000.0         HR
# 4      Eve  22.0      F  52000.0         IT

# %%
df.tail()
# Out:
#     Name    Age Gender   Salary Department
# 5  Frank   35.0    NaN  61000.0    Finance
# 6  Grace  120.0      F      NaN    Finance
# 7  Henry   28.0      M  59000.0         HR
# 8    Ivy   29.0      F  63000.0         IT
# 9   Jack   27.0      M  62000.0    Finance

# %%
df.shape
# Out:
# (10, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        10 non-null     object
#  1   Age         9 non-null      float64
#  2   Gender      9 non-null      object
#  3   Salary      9 non-null      float64
#  4   Department  10 non-null     object
# dtypes: float64(2), object(3)
# memory usage: 532.0+ bytes

# %%
df.describe()
# Out:
#               Age        Salary
# count    9.000000      9.000000
# mean    39.555556  57777.777778
# std     30.631320   4521.553322
# min     22.000000  50000.000000
# 25%     27.000000  55000.000000
# 50%     29.000000  59000.000000
# 75%     35.000000  61000.000000
# max    120.000000  63000.000000

# %%
df.isnull().sum()
# Out:
# Name          0
# Age           1
# Gender        1
# Salary        1
# Department    0
# dtype: int64

# %%
X=[40,30,43,10,23,10,42]
plt.plot(X)
plt.show()

# %%
import matplotlib.pyplot as plt
Age=[20,70,60,80,46]
plt.plot(Age)
plt.show()

# %%
x=[80,75,34,25,73,46]
y=[50000,40000,60000,35000,64000,40000]
plt.scatter(x,y,color='blue')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()

# %%
x=[80,75,34,25,73,46]
y=[50000,40000,60000,35000,64000,40000]
plt.bar(x,y,color='blue')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()

# %%
x=[80,75,34,25,73,46]
y=[50000,40000,60000,35000,64000,40000]
plt.hist(x)
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()

# %%
fig, ax = plt.subplots(1,3,figsize=(12,4))

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([3,8,7,9])
plt.subplot(2,9,7)
plt.plot(x,y)

# %%
y=np.array([54,10,29,20])
plt.pie(y)
plt.show()

# %%
x=[20,35,40,70]
labels=['Python','Java','C++','HTML']
plt.pie(x,labels=labels)
plt.title('Pie chart')
plt.show()

# %%
import seaborn as sns
x=[15,12,18,19,17,18,14]
y=[15,12,18,19,17,18,14]
sns.lineplot(x=x,y=y)
plt.show()

# %%
import seaborn as sns
x=[15,12,18,19,17,18,14]
y=[15,12,18,19,17,18,14]
sns.scatterplot(x=x,y=y)
plt.show()

# %%
import seaborn as sns
x=[15,12,18,19,17,18,14]
y=[15,12,18,19,17,18,14]
sns.barplot(x=x,y=y)
plt.show()

# %%
import seaborn as sns
x=[15,12,18,19,17,18,14]
y=[15,12,18,19,17,18,14]
sns.displot(x=x,y=y)
plt.show()

# %%
import seaborn as sns
X=[15,12,18,19,17,18,14]
Y=[15,12,18,19,17,18,14]
sns.displot(x=X)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("/content/preprocessing_dataset.csv")

print(df.columns)

sns.pairplot(df)

plt.show()
# Out:
# Index(['Name', 'Age', 'Gender', 'Salary', 'Department'], dtype='object')
