# %% [markdown]
# <a href="https://colab.research.google.com/github/vijayasrimurugan5-ui/HANDLING_MISSING_VALUES_AND_OUTLIERS/blob/main/HANDLING_OUTLIERS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/preprocessing_dataset.csv')

# %%
df1=df.copy()
df2=df.copy()

# %%
df.head()
# Out:
#       Name   Age Gender   Salary Department
# 0    Alice  25.0      F  50000.0         HR
# 1      Bob  30.0      M  60000.0    Finance
# 2  Charlie   NaN      M  55000.0         IT
# 3    David  40.0      M  58000.0         HR
# 4      Eve  22.0      F  52000.0         IT

# %%
df.tail()
# Out:
#     Name    Age Gender   Salary Department
# 5  Frank   35.0    NaN  61000.0    Finance
# 6  Grace  120.0      F      NaN    Finance
# 7  Henry   28.0      M  59000.0         HR
# 8    Ivy   29.0      F  63000.0         IT
# 9   Jack   27.0      M  62000.0    Finance

# %%
df.isnull().sum()
# Out:
# Name          0
# Age           1
# Gender        1
# Salary        1
# Department    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        10 non-null     object
#  1   Age         9 non-null      float64
#  2   Gender      9 non-null      object
#  3   Salary      9 non-null      float64
#  4   Department  10 non-null     object
# dtypes: float64(2), object(3)
# memory usage: 532.0+ bytes

# %%
df.describe()
# Out:
#               Age        Salary
# count    9.000000      9.000000
# mean    39.555556  57777.777778
# std     30.631320   4521.553322
# min     22.000000  50000.000000
# 25%     27.000000  55000.000000
# 50%     29.000000  59000.000000
# 75%     35.000000  61000.000000
# max    120.000000  63000.000000

# %%
df.shape
# Out:
# (10, 5)

# %%
# !pip install missingno
import missingno as msno
msno.bar(df)
# Out:
# ...
# <Axes: >

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
import seaborn as sns
sns.heatmap(df.isnull(),cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
df['Salary'].fillna(df['Salary'].mean(),inplace=True)
df['Gender'].fillna(df['Gender'].mode()[0],inplace=True)
df
# Out:
# /tmp/ipykernel_1006/3317915081.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(),inplace=True)
# /tmp/ipykernel_1006/3317915081.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
from sklearn.impute import SimpleImputer
imp=SimpleImputer(strategy='median')
df['Age']=imp.fit_transform(df[['Age']])
df
# Out:
#       Name         Age Gender        Salary Department
# 0    Alice   25.000000      F  50000.000000         HR
# 1      Bob   30.000000      M  60000.000000    Finance
# 2  Charlie   39.555556      M  55000.000000         IT
# 3    David   40.000000      M  58000.000000         HR
# 4      Eve   22.000000      F  52000.000000         IT
# 5    Frank   35.000000      M  61000.000000    Finance
# 6    Grace  120.000000      F  57777.777778    Finance
# 7    Henry   28.000000      M  59000.000000         HR
# 8      Ivy   29.000000      F  63000.000000         IT
# 9     Jack   27.000000      M  62000.000000    Finance

# %%
from sklearn.impute import SimpleImputer
imp=SimpleImputer(strategy='median')
df['Salary']=imp.fit_transform(df[['Salary']])
df
# Out:
#       Name         Age Gender        Salary Department
# 0    Alice   25.000000      F  50000.000000         HR
# 1      Bob   30.000000      M  60000.000000    Finance
# 2  Charlie   39.555556      M  55000.000000         IT
# 3    David   40.000000      M  58000.000000         HR
# 4      Eve   22.000000      F  52000.000000         IT
# 5    Frank   35.000000      M  61000.000000    Finance
# 6    Grace  120.000000      F  57777.777778    Finance
# 7    Henry   28.000000      M  59000.000000         HR
# 8      Ivy   29.000000      F  63000.000000         IT
# 9     Jack   27.000000      M  62000.000000    Finance

# %%
from sklearn.impute import SimpleImputer
imp=SimpleImputer(strategy='most_frequent')
df[['Gender']]=imp.fit_transform(df[['Gender']])
df
# Out:
#       Name         Age Gender        Salary Department
# 0    Alice   25.000000      F  50000.000000         HR
# 1      Bob   30.000000      M  60000.000000    Finance
# 2  Charlie   39.555556      M  55000.000000         IT
# 3    David   40.000000      M  58000.000000         HR
# 4      Eve   22.000000      F  52000.000000         IT
# 5    Frank   35.000000      M  61000.000000    Finance
# 6    Grace  120.000000      F  57777.777778    Finance
# 7    Henry   28.000000      M  59000.000000         HR
# 8      Ivy   29.000000      F  63000.000000         IT
# 9     Jack   27.000000      M  62000.000000    Finance

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
Q1=df['Age'].quantile(0.25)
Q3=df['Age'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
Outliers=df2[(df2['Age']<lower_bound) | (df2['Age']>upper_bound)]
Outliers
# Out:
#     Name    Age Gender  Salary Department
# 6  Grace  120.0      F     NaN    Finance

# %%
from scipy.stats import zscore
import numpy as np
df=df1.select_dtypes(include=[np.number])
z_scores = zscore(df)
Outlier=df[np.abs(z_scores) > 2.5]
print(Outlier)
# Out:
# Empty DataFrame
# Columns: [Age, Salary]
# Index: []

# %%
from sklearn.ensemble import IsolationForest
iso=IsolationForest(contamination=0.1)
df['Outliers']=iso.fit_predict(df[['Age','Salary']])
df[df['Outliers']==-1]
# Out:
#      Age  Salary  Outliers
# 6  120.0     NaN        -1

# %%
upper_limit = 60
df['Age_Winsorized'] = np.where(
    df['Age'] > upper_limit,
    upper_limit,
    df['Age']
)
print(df[['Age', 'Age_Winsorized']])
# Out:
#      Age  Age_Winsorized
# 0   25.0            25.0
# 1   30.0            30.0
# 2    NaN             NaN
# 3   40.0            40.0
# 4   22.0            22.0
# 5   35.0            35.0
# 6  120.0            60.0
# 7   28.0            28.0
# 8   29.0            29.0
# 9   27.0            27.0

# %%
df['Log_Salary'] = np.log(df['Salary'])
print(df[['Salary', 'Log_Salary']])
# Out:
#     Salary  Log_Salary
# 0  50000.0   10.819778
# 1  60000.0   11.002100
# 2  55000.0   10.915088
# 3  58000.0   10.968198
# 4  52000.0   10.858999
# 5  61000.0   11.018629
# 6      NaN         NaN
# 7  59000.0   10.985293
# 8  63000.0   11.050890
# 9  62000.0   11.034890

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(6,4))
sns.histplot(df['Log_Salary'], kde=True)
plt.title("Log Transformed Salary")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df['Age_Standardized'] = scaler.fit_transform(df[['Age_Winsorized']])
print(df[['Age_Winsorized', 'Age_Standardized']])
# Out:
#    Age_Winsorized  Age_Standardized
# 0            25.0         -0.729367
# 1            30.0         -0.267092
# 2             NaN               NaN
# 3            40.0          0.657457
# 4            22.0         -1.006731
# 5            35.0          0.195183
# 6            60.0          2.506555
# 7            28.0         -0.452002
# 8            29.0         -0.359547
# 9            27.0         -0.544457

# %%
from sklearn.preprocessing import MinMaxScaler
minmax = MinMaxScaler()
df['Salary_MinMax'] = minmax.fit_transform(df[['Salary']])
print(df[['Salary', 'Salary_MinMax']])
# Out:
#     Salary  Salary_MinMax
# 0  50000.0       0.000000
# 1  60000.0       0.769231
# 2  55000.0       0.384615
# 3  58000.0       0.615385
# 4  52000.0       0.153846
# 5  61000.0       0.846154
# 6      NaN            NaN
# 7  59000.0       0.692308
# 8  63000.0       1.000000
# 9  62000.0       0.923077

# %%
from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer(method='yeo-johnson')
df['Salary_Power'] = pt.fit_transform(df[['Salary']])
print(df[['Salary', 'Salary_Power']])
# Out:
#     Salary  Salary_Power
# 0  50000.0     -1.584221
# 1  60000.0      0.423668
# 2  55000.0     -0.809933
# 3  58000.0     -0.136350
# 4  52000.0     -1.319100
# 5  61000.0      0.741954
# 6      NaN           NaN
# 7  59000.0      0.131484
# 8  63000.0      1.464310
# 9  62000.0      1.088187

# %%
from scipy.stats import boxcox
import numpy as np
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='median')
df['Salary_BoxCox_Input'] = imputer.fit_transform(df[['Salary']])
df['Salary_BoxCox'], lambda_value = boxcox(df['Salary_BoxCox_Input'])
print(df[['Salary', 'Salary_BoxCox_Input', 'Salary_BoxCox']])
print("Lambda Value:", lambda_value)
# Out:
#     Salary  Salary_BoxCox_Input  Salary_BoxCox
# 0  50000.0              50000.0   1.893106e+31
# 1  60000.0              60000.0   6.580882e+31
# 2  55000.0              55000.0   3.631153e+31
# 3  58000.0              58000.0   5.219973e+31
# 4  52000.0              52000.0   2.475013e+31
# 5  61000.0              61000.0   7.367856e+31
# 6      NaN              59000.0   5.866817e+31
# 7  59000.0              59000.0   5.866817e+31
# 8  63000.0              63000.0   9.185178e+31
# 9  62000.0              62000.0   8.233803e+31
# Lambda Value: 6.83380346611101

# %% [markdown]
# ENCODING

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df1['Gender_encoder']=le.fit_transform(df1['Gender'])
df1
# Out:
#       Name    Age Gender   Salary Department  Gender_encoder
# 0    Alice   25.0      F  50000.0         HR               0
# 1      Bob   30.0      M  60000.0    Finance               1
# 2  Charlie    NaN      M  55000.0         IT               1
# 3    David   40.0      M  58000.0         HR               1
# 4      Eve   22.0      F  52000.0         IT               0
# 5    Frank   35.0    NaN  61000.0    Finance               2
# 6    Grace  120.0      F      NaN    Finance               0
# 7    Henry   28.0      M  59000.0         HR               1
# 8      Ivy   29.0      F  63000.0         IT               0
# 9     Jack   27.0      M  62000.0    Finance               1

# %%
from sklearn.preprocessing import OneHotEncoder
one=OneHotEncoder(sparse_output=False)
df1['Gender']=one.fit_transform(df1[['Gender']])
df1
# Out:
#       Name    Age  Gender   Salary Department  Gender_encoder
# 0    Alice   25.0     1.0  50000.0         HR               0
# 1      Bob   30.0     0.0  60000.0    Finance               1
# 2  Charlie    NaN     0.0  55000.0         IT               1
# 3    David   40.0     0.0  58000.0         HR               1
# 4      Eve   22.0     1.0  52000.0         IT               0
# 5    Frank   35.0     0.0  61000.0    Finance               2
# 6    Grace  120.0     1.0      NaN    Finance               0
# 7    Henry   28.0     0.0  59000.0         HR               1
# 8      Ivy   29.0     1.0  63000.0         IT               0
# 9     Jack   27.0     0.0  62000.0    Finance               1

# %%
df1 = pd.get_dummies(df1, columns=['Gender'], drop_first=True)
df1
# Out:
#       Name    Age   Salary Department  Gender_encoder  Gender_1.0
# 0    Alice   25.0  50000.0         HR               0        True
# 1      Bob   30.0  60000.0    Finance               1       False
# 2  Charlie    NaN  55000.0         IT               1       False
# 3    David   40.0  58000.0         HR               1       False
# 4      Eve   22.0  52000.0         IT               0        True
# 5    Frank   35.0  61000.0    Finance               2       False
# 6    Grace  120.0      NaN    Finance               0        True
# 7    Henry   28.0  59000.0         HR               1       False
# 8      Ivy   29.0  63000.0         IT               0        True
# 9     Jack   27.0  62000.0    Finance               1       False
